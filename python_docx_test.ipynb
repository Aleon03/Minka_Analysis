# %% [markdown]
# Pruebas para familiriamizarme con el python_docx y la creación de mapas de calor

# %%
import os
from docx.shared import Inches
from docx.share import RGBColor
from docx import Document

# %%
doc = Document()



doc.save('Minka.docx')

# %%
os.system('start .docx')
# Out:
# 0
