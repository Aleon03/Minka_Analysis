# %% [markdown]
# Álex León Bernabé
# # INICIO MINKA ANALYSIS
#
# ## Script con las funciones más útiles e importantes de la funcion de la API de /projects. Importante para el proyecto final que una de sus utilidades podria ser extraer papers de los proyectos que encontramos en MINKA.

# %%
# %pip install requests

import pandas as pd
import requests
import json
url = 'https://minka-sdg.org:4000/v1/projects'
response = requests.get(url, verify=False)
response.json()

# %% [markdown]
# ### PLACES

# %%
url = 'https://minka-sdg.org:4000/v1/places/155'
response = requests.get(url, verify=False)
response.json()
# Out:
# c:\Users\alexl\anaconda3\envs\.conda\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'minka-sdg.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'total_results': 1,
#  'page': 1,
#  'per_page': 1,
#  'results': [{'ancestor_place_ids': None,
#    'bounding_box_geojson': {'coordinates': [[[19.646484375, 34.9344726562],
#       [19.646484375, 41.7437988281],
#       [28.2318359375, 41.7437988281],
#       [28.2318359375, 34.9344726562],
#       [19.646484375, 34.9344726562]]],
#     'type': 'Polygon'},
#    'bbox_area': 58.46045908949381,
#    'admin_level': 0,
#    'place_type': 12,
#    'name': 'Greece',
#    'location': '39.0746962307,22.9555579369',
#    'id': 155,
#    'display_name': 'Greece',
#    'uuid': '2500502e-746f-402c-aabb-ac56f19224a5',
#    'slug': 'greece',
# ...
