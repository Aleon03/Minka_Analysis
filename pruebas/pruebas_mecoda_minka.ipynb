# %%
import pandas as pd
from mecoda_minka import get_obs, get_dfs

# %%
obs = get_obs(id_project=264, grade="research", taxon_id=12)
df_obs, df_photos = get_dfs(obs)
# Out:
# Generating list of observations:
# https://api.minka-sdg.org/v1/observations?project_id=264&taxon_id=12&quality_grade=research&per_page=200
# Total observations to download: 1228
# Number of elements: 200
# Number of elements: 400
# Number of elements: 600
# Number of elements: 800
# Number of elements: 1000
# Number of elements: 1200
# Number of elements: 1228

# %%
obs[0]
# Out:
# Observation(id=432738, captive=False, created_at=datetime.datetime(2025, 4, 9, 9, 45, 40, tzinfo=TzInfo(+02:00)), updated_at=datetime.datetime(2025, 4, 9, 15, 37, 6, tzinfo=TzInfo(+02:00)), observed_on=datetime.date(2025, 4, 7), time_observed_at=datetime.datetime(2025, 4, 7, 10, 29, tzinfo=TzInfo(+02:00)), description=None, iconic_taxon='plantae', taxon_id=252738, taxon_name='Papaver rhoeas', taxon_rank='species', taxon_ancestry='1/12/257878/263906/31/1248/1247/39038', latitude=41.2810111136, longitude=2.0853588448, obscured=False, place_name='Platja de la Roberta', quality_grade='research', user_id=15, user_login='mediambient_ajelprat', license_obs='cc-by-nc', photos=[Photo(id=581334, large_url='https://minka-sdg.org/attachments/local_photos/files/581334/large.jpeg', medium_url='https://minka-sdg.org/attachments/local_photos/files/581334/medium.jpeg', small_url='https://minka-sdg.org/attachments/local_photos/files/581334/small.jpeg', license_photo='cc-by-nc', attribution='(c) mediam
# ...

# %%
df_obs, df_photos = get_dfs(obs)

# %%
df_obs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1228 entries, 0 to 1227
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1228 non-null   int64
#  1   created_at                        1228 non-null   object
#  2   updated_at                        1228 non-null   object
#  3   observed_on                       1228 non-null   object
#  4   observed_on_time                  1228 non-null   object
#  5   iconic_taxon                      1228 non-null   object
#  6   taxon_id                          1228 non-null   object
#  7   taxon_rank                        1228 non-null   object
#  8   taxon_name                        1228 non-null   object
#  9   latitude                          1228 non-null   float64
#  10  longitude                         1228 non-null   float64
# ...

# %%
df_photos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1636 entries, 0 to 1635
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1636 non-null   int64
#  1   photos_id          1636 non-null   object
#  2   iconic_taxon       1636 non-null   object
#  3   taxon_name         1636 non-null   object
#  4   photos_medium_url  1636 non-null   object
#  5   user_login         1636 non-null   object
#  6   latitude           1636 non-null   float64
#  7   longitude          1636 non-null   float64
#  8   license_photo      1636 non-null   object
#  9   attribution        1636 non-null   object
#  10  path               1636 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 153.4+ KB

# %%
df_photos.head(1)
# Out:
#        id photos_id iconic_taxon      taxon_name  \
# 0  432738    581334      plantae  Papaver rhoeas
#
#                                    photos_medium_url            user_login  \
# 0  https://minka-sdg.org/attachments/local_photos...  mediambient_ajelprat
#
#     latitude  longitude license_photo  \
# 0  41.281011   2.085359      cc-by-nc
#
#                                          attribution               path
# 0  (c) mediambient_ajelprat, some rights reserved...  432738_581334.jpg

# %%
df_obs["observed_on"] = pd.to_datetime(df_obs["observed_on"], format="%Y-%m-%d")

# %%
df_obs.groupby("observed_on")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1228 entries, 0 to 1227
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1228 non-null   int64
#  1   created_at                        1228 non-null   object
#  2   updated_at                        1228 non-null   object
#  3   observed_on                       1228 non-null   datetime64[ns]
#  4   observed_on_time                  1228 non-null   object
#  5   iconic_taxon                      1228 non-null   object
#  6   taxon_id                          1228 non-null   object
#  7   taxon_rank                        1228 non-null   object
#  8   taxon_name                        1228 non-null   object
#  9   latitude                          1228 non-null   float64
#  10  longitude                         1228 non-null   float64
# ...

# %%
import requests

session = requests.Session()
url = "https://api.minka-sdg.org/v1/observations"

response = session.get(url).json()

# %%
df_obs["year"] = df_obs["observed_on"].dt.year

# %%
df_obs["month"] = df_obs["observed_on"].dt.month
